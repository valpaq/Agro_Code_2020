# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('data/train_290_without_low1.csv')
test = pd.read_csv('data/test_dropped_290_without_nans.csv')
y_train=train['Culture']
train=train.drop('Culture',axis=1)
print(train.shape, test.shape)
# Out:
# (2828, 293) (939, 293)

# %%
train.drop(['0','1','2'],axis=1,inplace=True)
test.drop(['0','1','2'],axis=1,inplace=True)

# %%
pca = PCA(.99999999).fit(train)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
# Out:
# Text(0, 0.5, 'cumulative explained variance')

# %%
for i,j in enumerate(np.cumsum(pca.explained_variance_ratio_)):
    print(i,j)
# Out:
# 0 0.6566945590103543
# 1 0.7576872838326917
# 2 0.8524324887248459
# 3 0.8958198968152301
# 4 0.9319307627902812
# 5 0.9536815844110156
# 6 0.9658518519408863
# 7 0.9739795946149574
# 8 0.980283265339224
# 9 0.9843530594668061
# 10 0.9877670065366503
# 11 0.9905018121162438
# 12 0.9923055904399484
# 13 0.9935448919078088
# 14 0.9946425563522064
# 15 0.995499383865812
# 16 0.9962700074298558
# 17 0.9968128863003581
# 18 0.9972892554721647
# 19 0.9977129226170699
# 20 0.9980894156902702
# 21 0.9983486535211601
# 22 0.9985593937665301
# 23 0.9987464148387586
# 24 0.9989118788652525
# 25 0.9990636026928247
# 26 0.9991797232370497
# 27 0.9992813776240421
# 28 0.9993699276951976
# 29 0.9994392745157243
# 30 0.9995020794138724
# 31 0.9995563721396388
# 32 0.9996024656137781
# 33 0.999643559088809
# 34 0.9996769632400582
# 35 0.9997080710608648
# 36 0.9997363188069007
# 37 0.9997615486030196
# 38 0.9997859878088097
# 39 0.9998056211738577
# 40 0.9998224126468009
# 41 0.9998381509644604
# 42 0.9998509941114061
# 43 0.9998629476523487
# 44 0.9998733513415756
# 45 0.9998832801268907
# 46 0.9998920198460834
# 47 0.9999003039550071
# 48 0.9999076148950525
# 49 0.9999143393079215
# 50 0.9999199120681582
# 51 0.9999249722338774
# 52 0.9999295553323057
# 53 0.9999340602062833
# 54 0.9999381436852797
# 55 0.9999417862748935
# 56 0.9999452139873559
# 57 0.999948247970467
# 58 0.9999510253650649
# 59 0.9999535278507241
# 60 0.9999559529382062
# 61 0.999958306811453
# 62 0.9999606071168818
# 63 0.9999626222018868
# 64 0.9999645561703083
# 65 0.9999662815907334
# 66 0.9999679087378687
# 67 0.9999694921778334
# 68 0.999970888865837
# 69 0.9999722442098217
# 70 0.9999734600720273
# 71 0.999974642144536
# 72 0.9999757789047393
# 73 0.9999768599573002
# 74 0.999977828642479
# 75 0.9999787482631837
# 76 0.9999796339607577
# 77 0.9999804686238124
# 78 0.9999812815212972
# 79 0.9999820581378918
# 80 0.9999827792960791
# 81 0.9999834781364753
# 82 0.9999841441386544
# 83 0.9999847764270179
# 84 0.9999853297530924
# 85 0.9999858552379131
# 86 0.9999863554373931
# 87 0.9999868340759905
# 88 0.9999873030540313
# 89 0.9999877487147644
# 90 0.9999881793440193
# 91 0.9999885847923319
# 92 0.9999889702122244
# 93 0.9999893493046794
# 94 0.9999897142428127
# 95 0.9999900643297414
# 96 0.9999903917697198
# 97 0.9999907054288307
# 98 0.9999910159684207
# 99 0.9999913119282628
# 100 0.9999916001366285
# 101 0.9999918680363211
# 102 0.9999921272637132
# 103 0.9999923799222614
# 104 0.9999926182531259
# 228 0.999999744060894
# 229 0.9999997528051654
# 230 0.9999997613910312
# 231 0.9999997697135203
# 232 0.9999997776162554
# 233 0.9999997852804415
# 234 0.9999997928261546
# 235 0.9999998002021008
# 236 0.9999998073259605
# 237 0.999999813982872
# 238 0.9999998205028549
# 239 0.9999998269136399
# 240 0.9999998332311644
# 241 0.999999839446961
# 242 0.9999998455183527
# 243 0.9999998513922245
# 244 0.9999998571978386
# 245 0.9999998628584961
# 246 0.9999998684269709
# 247 0.9999998738488287
# 248 0.9999998792246801
# 249 0.9999998844363034
# 250 0.9999998895569878
# 251 0.9999998946229793
# 252 0.9999998996323924
# 253 0.9999999045916894
# 254 0.999999909278775
# 255 0.9999999138298873
# 256 0.999999918159314
# 257 0.9999999224259265
# 258 0.9999999266055692
# 259 0.9999999305820882
# 260 0.9999999344857992
# 261 0.999999938276497
# 262 0.9999999420510798
# 263 0.9999999456858336
# 264 0.9999999491585522
# 265 0.9999999524231821
# 266 0.9999999555991885
# 267 0.9999999587261303
# 268 0.9999999617468669
# 269 0.9999999646817975
# 270 0.99999996750687
# 271 0.999999970190131
# 272 0.9999999728273952
# 273 0.9999999753122187
# 274 0.9999999777654388
# 275 0.9999999800802594
# 276 0.9999999823025251
# 277 0.9999999843801394
# 278 0.9999999864158613
# 279 0.9999999883423585
# 280 0.9999999901870058

# %%
train_pca=pca.transform(train)

# %%
test_pca=pca.transform(test)

# %%
train_pca=pd.DataFrame(train_pca)
test_pca=pd.DataFrame(test_pca)

# %%
train = pd.read_csv('data/train_dropped_290_without_nans.csv')
test = pd.read_csv('data/test_dropped_290_without_nans.csv')

# %%
for i in ['0','1','2']:
    train_pca[i]=train[i]
    test_pca[i]=test[i]
train['Culture']=y_train

# %%
train_pca.to_csv('data/train_pca_0.99999999.csv',index=False)

# %%
test_pca.to_csv('data/test_pca_0.99999999.csv',index=False)

# %%
train = pd.read_csv('data/train_290_without_low1.csv')
test = pd.read_csv('data/test_dropped_290_without_nans.csv')
xtrain=train.drop(['0','1','2','Culture'],axis=1)
xtest=test.drop(['0','1','2'],axis=1)
pca = PCA(.9999999).fit(xtrain)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
# Out:
# Text(0, 0.5, 'cumulative explained variance')

# %%
train_pca=pca.transform(xtrain)
test_pca=pca.transform(xtest)
train_pca=pd.DataFrame(train_pca)
test_pca=pd.DataFrame(test_pca)
for i in ['0','1','2']:
    train_pca[i]=train[i]
    test_pca[i]=test[i]
train_pca['Culture']=train['Culture']
train_pca.to_csv('data/train_pca_0.9999999.csv',index=False)
test_pca.to_csv('data/test_pca_0.9999999.csv',index=False)

# %%
train = pd.read_csv('data/train_290_without_low1.csv')
test = pd.read_csv('data/test_dropped_290_without_nans.csv')
xtrain=train.drop(['0','1','2','Culture'],axis=1)
xtest=test.drop(['0','1','2'],axis=1)
pca = PCA(.999999).fit(xtrain)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
# Out:
# Text(0, 0.5, 'cumulative explained variance')

# %%
train_pca=pca.transform(xtrain)
test_pca=pca.transform(xtest)
train_pca=pd.DataFrame(train_pca)
test_pca=pd.DataFrame(test_pca)
for i in ['0','1','2']:
    train_pca[i]=train[i]
    test_pca[i]=test[i]
train_pca['Culture']=train['Culture']
train_pca.to_csv('data/train_pca_0.999999.csv',index=False)
test_pca.to_csv('data/test_pca_0.999999.csv',index=False)
