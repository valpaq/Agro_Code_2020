# %%
import pandas as pd

# %%
pred=pd.read_csv('preds/fastai0.csv')
for i in [1,6,7,15,42,70,80,96,99,154,482,666,854,123456,123465]:
    p1=pd.read_csv('preds/fastai'+str(i)+'.csv')
    pred=pd.concat([pred,p1],axis=1)
pred
# Out:
#      Culture  Culture  Culture  Culture  Culture  Culture  Culture  Culture  \
# 0        4.0      4.0      4.0      4.0      4.0      4.0      4.0      4.0
# 1       12.0     12.0     12.0     12.0     12.0     12.0     13.0     12.0
# 2       12.0     12.0     16.0      7.0     10.0     12.0     16.0      7.0
# 3        7.0      7.0      3.0      3.0      7.0      3.0      3.0      3.0
# 4        4.0      4.0      4.0      4.0      4.0      4.0      4.0      4.0
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 934     10.0     10.0     10.0     10.0     10.0     16.0     10.0     10.0
# 935     10.0      7.0      7.0      7.0      7.0     19.0      7.0     10.0
# 936      7.0     10.0      7.0      7.0      7.0      3.0      7.0     10.0
# 937     12.0     12.0     12.0     12.0     12.0     12.0     12.0     12.0
# 938      4.0      4.0      4.0      4.0      4.0      4.0      4.0      4.0
#
# ...

# %%
pred.columns=['0','1','6','7','15','42','70','80','96','99','154','482','666','854','123456','123465']

# %%
pred
# Out:
#         0     1     6     7    15    42    70    80    96    99   154   482  \
# 0     4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0
# 1    12.0  12.0  12.0  12.0  12.0  12.0  13.0  12.0  12.0  12.0  12.0  12.0
# 2    12.0  12.0  16.0   7.0  10.0  12.0  16.0   7.0  16.0  16.0  10.0  10.0
# 3     7.0   7.0   3.0   3.0   7.0   3.0   3.0   3.0  16.0   7.0   7.0   3.0
# 4     4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 934  10.0  10.0  10.0  10.0  10.0  16.0  10.0  10.0  10.0  10.0  10.0  10.0
# 935  10.0   7.0   7.0   7.0   7.0  19.0   7.0  10.0   7.0  10.0  16.0  10.0
# 936   7.0  10.0   7.0   7.0   7.0   3.0   7.0  10.0   7.0   7.0   7.0   7.0
# 937  12.0  12.0  12.0  12.0  12.0  12.0  12.0  12.0  12.0  12.0  14.0  14.0
# 938   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0
#
#       666   854  123456  123465
# ...

# %%
final=[]
for i in range(len(pred.index)):
    final.append(pred.loc[i].value_counts().index.tolist()[0])
    print(pred.loc[i].value_counts())
# Out:
# 4.0    16
# Name: 0, dtype: int64
# 12.0    15
# 13.0     1
# Name: 1, dtype: int64
# 16.0    5
# 12.0    5
# 10.0    4
# 7.0     2
# Name: 2, dtype: int64
# 3.0     8
# 7.0     7
# 16.0    1
# Name: 3, dtype: int64
# 4.0    16
# Name: 4, dtype: int64
# 4.0    16
# Name: 5, dtype: int64
# 17.0    5
# 10.0    4
# 8.0     4
# 16.0    2
# 5.0     1
# Name: 6, dtype: int64
# 5.0    11
# 8.0     4
# 4.0     1
# Name: 7, dtype: int64
# 19.0    14
# 7.0      2
# Name: 8, dtype: int64
# 4.0    16
# Name: 9, dtype: int64
# 4.0    16
# Name: 10, dtype: int64
# 3.0     9
# 16.0    4
# 7.0     3
# Name: 11, dtype: int64
# 4.0    16
# Name: 12, dtype: int64
# 9.0     9
# 5.0     5
# 14.0    2
# Name: 13, dtype: int64
# 9.0    16
# Name: 14, dtype: int64
# 9.0    15
# 8.0     1
# Name: 15, dtype: int64
# 4.0    16
# Name: 16, dtype: int64
# 3.0     11
# 7.0      3
# 10.0     1
# 16.0     1
# Name: 17, dtype: int64
# 5.0    8
# 1.0    7
# 8.0    1
# Name: 18, dtype: int64
# 4.0    14
# 3.0     2
# ...

# %%
pred['final']=pd.Series(final)
pred
# Out:
#         0     1     6     7    15    42    70    80    96    99   154   482  \
# 0     4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0
# 1    12.0  12.0  12.0  12.0  12.0  12.0  13.0  12.0  12.0  12.0  12.0  12.0
# 2    12.0  12.0  16.0   7.0  10.0  12.0  16.0   7.0  16.0  16.0  10.0  10.0
# 3     7.0   7.0   3.0   3.0   7.0   3.0   3.0   3.0  16.0   7.0   7.0   3.0
# 4     4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 934  10.0  10.0  10.0  10.0  10.0  16.0  10.0  10.0  10.0  10.0  10.0  10.0
# 935  10.0   7.0   7.0   7.0   7.0  19.0   7.0  10.0   7.0  10.0  16.0  10.0
# 936   7.0  10.0   7.0   7.0   7.0   3.0   7.0  10.0   7.0   7.0   7.0   7.0
# 937  12.0  12.0  12.0  12.0  12.0  12.0  12.0  12.0  12.0  12.0  14.0  14.0
# 938   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0   4.0
#
#       666   854  123456  123465  final
# ...

# %%
pd.Series(pred['final']).to_csv('preds/final_fastai.csv', index=False, header=['Culture'])
